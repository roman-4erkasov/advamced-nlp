# %%
import codecs

def read_all_tokens(path):
    return [line.strip().split() for line in codecs.open(path, 'r', 'utf8')]

# %%
# from nltk.stem import PorterStemmer
# stemmer = PorterStemmer()

import nltk
stemmer = nltk.stem.SnowballStemmer('english')

# %%
stemmer.stem("wunderfull")
# Out:
# 'wunderful'

# %%
path_toks_dev_en = "../test/en-cs.en.dev.tokens"
# path_toks_dev_en = "../test/en-cs.en.dev.tokens"
# corpus_en = read_all_tokens(path_toks_dev_en)

# %%
path_lemm_dev_en = "../training/en-cs.cs.train.lemmas.10K"
lemmas_en = read_all_tokens(path_lemm_dev_en)

# %%
lemmas_en
# Out:
# [['následný',
#   'postup',
#   'na',
#   'základ',
#   'usnesení',
#   'parlament',
#   ':',
#   'viz',
#   'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['budoucí',
#   'akce',
#   'v',
#   'oblast',
#   'patent',
#   '(',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '23.55', ')'],
#  ['zahájení', 'zasedání'],
#  ['(',
#   '&quot;',
#   'συνεδρίαση',
#   'αρχίζει',
#   'στις',
#   '9',
#   'π',
#   '.',
#   'μ',
#   '.',
#   ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['1', '.'],
#  ['dohoda',
#   'ES',
#   '/',
#   'Bulharsko',
#   ':',
#   'účast',
#   'na',
#   'činnost',
#   'evropský',
#   'monitorovací',
#   'centrum',
#   'pro',
#   'droga',
#   'a',
#   'drogový',
#   'závislost',
#   '(',
#   'hlasování',
#   ')'],
#  ['2', '.'],
#  ['dohoda',
#   'ES',
#   '/',
#   'Rumunsko',
#   ':',
#   'účast',
#   'na',
#   'činnost',
#   'evropský',
#   'monitorovací',
#   'centrum',
#   'pro',
#   'droga',
#   'a',
#   'drogový',
#   'závislost',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['dohoda',
#   'ES',
#   '/',
#   'Turecko',
#   ':',
#   'účast',
#   'na',
#   'činnost',
#   'evropský',
#   'monitorovací',
#   'centrum',
#   'pro',
#   'droga',
#   'a',
#   'drogový',
#   'závislost',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['dohoda',
#   'mezi',
#   'evropský',
#   'společenství',
#   'a',
#   'Singapur',
#   'o',
#   'některý',
#   'aspekt',
#   'letecký',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['dohoda',
#   'mezi',
#   'ES',
#   'a',
#   'Austrálie',
#   'o',
#   'některý',
#   'aspekt',
#   'letecký',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['dohoda',
#   'ES',
#   '/',
#   'nový',
#   'Zéland',
#   'o',
#   'některý',
#   'aspekt',
#   'letecký',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['dohoda',
#   'ES',
#   '/',
#   'Uruguay',
#   'o',
#   'některý',
#   'aspekt',
#   'letecký',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['8', '.'],
#  ['dohoda',
#   'mezi',
#   'evropský',
#   'společenství',
#   'a',
#   'maledivský',
#   'republika',
#   'o',
#   'některý',
#   'aspekt',
#   'letecký',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['9', '.'],
#  ['řízení',
#   'evropský',
#   'družicový',
#   'navigační',
#   'program',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['požadovaný',
#   'jakost',
#   'voda',
#   'pro',
#   'měkkýš',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['klamavý',
#   'a',
#   'srovnávací',
#   'reklama',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['doba',
#   'ochrana',
#   'autorský',
#   'právo',
#   'a',
#   'určitý',
#   'právo',
#   's',
#   'on',
#   'související',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['13', '.'],
#  ['právo',
#   'na',
#   'pronájem',
#   'a',
#   'půjčování',
#   'a',
#   'některý',
#   'právo',
#   'v',
#   'oblast',
#   'duševní',
#   'vlastnictví',
#   'související',
#   's',
#   'autorský',
#   'právo',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['ochrana',
#   'proti',
#   'štítenka',
#   'zhoubný',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['15', '.'],
#  ['glukóza',
#   'a',
#   'laktóza',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['16', '.'],
#  ['změna',
#   'článek',
#   '3',
#   'a',
#   '4',
#   'jednací',
#   'řád',
#   'parlament',
#   '(',
#   'hlasování',
#   ')'],
#  ['19', '.'],
#  ['statistický',
#   'klasifikace',
#   'ekonomický',
#   'činnost',
#   'Naka',
#   '(',
#   'hlasování',
#   ')'],
#  ['20', '.'],
#  ['mimořádný',
#   'finanční',
#   'pomoc',
#   'společenství',
#   'Kosovo',
#   '(',
#   'hlasování',
#   ')'],
#  ['21', '.'],
#  ['evropský', 'agentura', 'pro', 'obnova', '(', 'hlasování', ')'],
#  ['25', '.'],
#  ['dobrý',
#   'životní',
#   'podmínka',
#   'a',
#   'ochrana',
#   'zvíře',
#   '(',
#   '2006',
#   '-',
#   '2010',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['26', '.'],
#  ['následný',
#   'krok',
#   'po',
#   'zpráva',
#   'o',
#   'soutěž',
#   'v',
#   'oblast',
#   'volný',
#   'profese',
#   '(',
#   'hlasování',
#   ')'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['přerušení', 'zasedání'],
#  ['(', 's', 'levanta', 'la', 'sesión', 'a', 'laso', '12.10', 'horas', ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['podepisování',
#   'akt',
#   'přijatý',
#   'postup',
#   'spolurozhodování',
#   ':',
#   'viz',
#   'zápis'],
#  ['sdělení', 'předsednictvo', ':', 'viz', 'zápis'],
#  ['vztah',
#   'mezi',
#   'evropský',
#   'unie',
#   'a',
#   'Rusko',
#   'po',
#   'vražda',
#   'novinářka',
#   'Anna',
#   'Politkovská',
#   '(',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['petice', ':', 'viz', 'zápis'],
#  ['převod', 'prostředek', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['následný',
#   'postup',
#   'na',
#   'základ',
#   'usnesení',
#   'parlament',
#   ':',
#   'viz',
#   'zápis'],
#  ['písemný',
#   'prohlášení',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '22.20', ')'],
#  ['rozprava',
#   'o',
#   'případ',
#   'porušování',
#   'lidský',
#   'právo',
#   ',',
#   'demokracie',
#   'a',
#   'právní',
#   'stát',
#   '(',
#   'oznámení',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['1', '.'],
#  ['organizace',
#   'spojený',
#   'národ',
#   ':',
#   'schvalování',
#   'vozidlo',
#   'kategorie',
#   'm',
#   '2',
#   'nebo',
#   'M',
#   '3',
#   'z',
#   'hledisko',
#   'jeho',
#   'celkový',
#   'konstrukce',
#   '(',
#   'hlasování',
#   ')'],
#  ['2', '.'],
#  ['přistoupení',
#   'Bulharsko',
#   'a',
#   'Rumunsko',
#   '-',
#   'nábor',
#   'úředník',
#   'evropský',
#   'společenství',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['změna', 'stanovy', 'společný', 'podnik', 'Galileo', '(', 'hlasování', ')'],
#  ['4', '.'],
#  ['finanční',
#   'účast',
#   'Norsko',
#   'na',
#   'práce',
#   'evropský',
#   'monitorovací',
#   'centrum',
#   'pro',
#   'droga',
#   'a',
#   'drogový',
#   'závislost',
#   '(',
#   'EMCDDA',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['žádost',
#   'o',
#   'zbavení',
#   'imunita',
#   'Bogdan',
#   'Golika',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['žádost',
#   'na',
#   'ochrana',
#   'imunita',
#   'a',
#   'výsada',
#   'pan',
#   'Maria',
#   'Borghezia',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['návrh',
#   'opravný',
#   'rozpočet',
#   'evropský',
#   'unie',
#   'číslo',
#   '.',
#   '3',
#   '/',
#   '2006',
#   'na',
#   'rozpočtový',
#   'rok',
#   '2006',
#   '(',
#   'hlasování',
#   ')'],
#  ['8', '.'],
#  ['návrh',
#   'opravný',
#   'rozpočet',
#   'evropský',
#   'unie',
#   'číslo',
#   '.',
#   '5',
#   '/',
#   '2006',
#   'na',
#   'rozpočtový',
#   'rok',
#   '2006',
#   '(',
#   'hlasování',
#   ')'],
#  ['9', '.'],
#  ['strategický',
#   'partnerství',
#   'mezi',
#   'evropský',
#   'unie',
#   'a',
#   'jihoafrický',
#   'republika',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['finanční',
#   'nástroj',
#   'pro',
#   'životní',
#   'prostředí',
#   '(',
#   'Life',
#   '+',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['program',
#   'podpora',
#   'evropský',
#   'audiovizuální',
#   'odvětví',
#   '(',
#   'Media',
#   '2007',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['program', 'kultura', '(', '2007', '-', '2013', ')', '(', 'hlasování', ')'],
#  ['13', '.'],
#  ['mechanismus',
#   'společenství',
#   'v',
#   'oblast',
#   'civilní',
#   'ochrana',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['opatření',
#   'k',
#   'provedení',
#   'směrnice',
#   '&quot;',
#   'průhlednost',
#   '&quot;',
#   'a',
#   '&quot;',
#   'Prospekta',
#   '&quot;',
#   '(',
#   'úroveň',
#   '2',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['15', '.'],
#  ['opatření',
#   'k',
#   'provedení',
#   'směrnice',
#   '&quot;',
#   'průhlednost',
#   '&quot;',
#   'a',
#   '&quot;',
#   'Prospekta',
#   '&quot;',
#   '(',
#   'úroveň',
#   '2',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['16', '.'],
#  ['přistěhovalectví',
#   'žena',
#   '-',
#   'úloha',
#   'a',
#   'postavení',
#   'přistěhovalkyně',
#   'v',
#   'evropský',
#   'unie',
#   '(',
#   'hlasování',
#   ')'],
#  ['17', '.'],
#  ['vymáhání', 'prostředek', 'společenství', '(', 'hlasování', ')'],
#  ['That', 'concludes', 'the', 'vot', '.'],
#  ['hlasování'],
#  ['the', 'next', 'it', 'be', 'the', 'vote', '.'],
#  ['(',
#   'fórum',
#   'the',
#   'result',
#   'and',
#   'other',
#   'details',
#   'on',
#   'the',
#   'vot',
#   ':',
#   'see',
#   'Minutes',
#   ')'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'the',
#   'sitting',
#   'was',
#   'suspended',
#   'atmosféra',
#   '12.35',
#   'and',
#   'resumed',
#   'atmosféra',
#   '15.00',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'dílčí', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(',
#   'Posiedzenie',
#   'zostało',
#   'zamknięte',
#   'o',
#   'godz',
#   '.',
#   '23.50',
#   '.',
#   ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 's', 'abre', 'la', 'sesión', 'a', 'laso', '9.05', 'horas', ')'],
#  ['členství', 'v', 'politický', 'skupina', ':', 'viz', 'zápi'],
#  ['3', '.'],
#  ['program',
#   '&quot;',
#   'mládež',
#   'v',
#   'akce',
#   '&quot;',
#   'na',
#   'období',
#   '2007',
#   '?',
#   '?',
#   '-2013',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['akční',
#   'program',
#   'v',
#   'oblast',
#   'celoživotní',
#   'vzdělávání',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['program',
#   '&quot;',
#   'Evropa',
#   'pro',
#   'občan',
#   '&quot;',
#   '(',
#   '2007',
#   '-',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['omezení',
#   'uvádění',
#   'na',
#   'trh',
#   'a',
#   'používání',
#   'perfluoroktansulfonátů',
#   '(',
#   'hlasování',
#   ')'],
#  ['9', '.'],
#  ['zřízení',
#   ',',
#   'provoz',
#   'a',
#   'využívání',
#   'SIS',
#   'II',
#   '(',
#   'rozhodnutí',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['vztah',
#   'mezi',
#   'evropský',
#   'unie',
#   'a',
#   'Rusko',
#   'po',
#   'vražda',
#   'novinářka',
#   'Anna',
#   'Politkovská',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['rakovina', 'prs', '(', 'hlasování', ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '00.10', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 'Posiedzenie', 'zostało', 'otwarte', 'o', 'godz', '.', '10.05', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['2', '.'],
#  ['návrh',
#   'souhrnný',
#   'rozpočet',
#   'na',
#   'rok',
#   '2007',
#   '(',
#   'oddíl',
#   'III',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['řízení',
#   'rybářský',
#   'loďstvo',
#   'zapsaný',
#   'v',
#   'vzdálený',
#   'region',
#   'společenství',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['Moldavsko', '/', 'Podněstří', '(', 'hlasování', ')'],
#  ['7', '.'],
#  ['Gruzie', '(', 'jižní', 'Osetie', ')', '(', 'hlasování', ')'],
#  ['8', '.'],
#  ['vývoz', 'toxický', 'odpad', 'do', 'Afrika', '(', 'hlasování', ')'],
#  ['9', '.'],
#  ['trestněprávní', 'ochrana', 'životní', 'prostředí', '(', 'hlasování', ')'],
#  ['10', '.'],
#  ['evropský',
#   '-',
#   'středomořský',
#   'dohoda',
#   'o',
#   'přidružení',
#   'EU',
#   '/',
#   'Sýrie',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['konference', 'o', 'změna', 'klima', 'v', 'Nairobi', '(', 'hlasování', ')'],
#  ['12', '.'],
#  ['integrovaný',
#   'evropský',
#   'akční',
#   'program',
#   'pro',
#   'vnitrozemský',
#   'vodní',
#   'doprava',
#   '&quot;',
#   'NAIADES',
#   '&quot;',
#   '(',
#   'hlasování',
#   ')'],
#  ['hlasování'],
#  ['Pasam', 'al', 'turno', 'de', 'votaciones', '.'],
#  ['(',
#   'para',
#   'los',
#   'resultados',
#   'y',
#   'otros',
#   'detalles',
#   'de',
#   'la',
#   'votación',
#   ':',
#   'véase',
#   'elektrický',
#   'Acta',
#   ')'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'sesión',
#   ',',
#   'suspendida',
#   'a',
#   'laso',
#   '13.50',
#   'horas',
#   ',',
#   'se',
#   'reanuda',
#   'a',
#   'laso',
#   '15.05',
#   'horas',
#   ')'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['sdělení', 'společný', 'postoj', 'rada', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['1', '.'],
#  ['tibet', '(', 'hlasování', ')'],
#  ['2', '.'],
#  ['proces', 's', 'Riosem', 'Montt', '(', 'hlasování', ')'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   'uložený',
#   'v',
#   'rejstřík',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['přerušení', 'zasedání'],
#  ['být',
#   'déclare',
#   'interrompue',
#   'la',
#   'session',
#   'jít',
#   'Parlement',
#   'européen',
#   '.'],
#  ['(', 'Le', 'séance', 'est', 'levée', 'à', '16', 'h', '25', ')'],
#  ['převod', 'prostředek', ':', 'viz', 'zápis'],
#  ['petice', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['písemný',
#   'prohlášení',
#   'a',
#   'otázka',
#   'k',
#   'ústní',
#   'zodpovězení',
#   '(',
#   'předložení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['podepisování',
#   'akt',
#   'přijatý',
#   'postup',
#   'spolurozhodování',
#   ':',
#   'viz',
#   'zápis'],
#  ['návrh',
#   'souhrnný',
#   'rozpočet',
#   'na',
#   'rozpočtový',
#   'rok',
#   '2007',
#   '(',
#   'lhůta',
#   'pro',
#   'předložení',
#   'předloha',
#   'změna',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'the', 'sitting', 'was', 'closed', 'atmosféra', '22.45', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 'die', 'Sitzung', 'wird', 'um', '9.00', 'Uhry', 'eröffnet', '.', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['rozprava',
#   'o',
#   'případ',
#   'porušování',
#   'lidský',
#   'právo',
#   ',',
#   'demokracie',
#   'a',
#   'právní',
#   'stát',
#   '(',
#   'oznámení',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['1', '.'],
#  ['režim',
#   'přímý',
#   'podpora',
#   'v',
#   'rámec',
#   'společný',
#   'zemědělský',
#   'politika',
#   'a',
#   'podpora',
#   'pro',
#   'rozvoj',
#   'venkov',
#   'z',
#   'evropský',
#   'zemědělský',
#   'fond',
#   'pro',
#   'rozvoj',
#   'venkov',
#   '(',
#   'EZFRV',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['2', '.'],
#  ['dohoda',
#   'mezi',
#   'ES',
#   'a',
#   'kanada',
#   'o',
#   'spolupráce',
#   'v',
#   'oblast',
#   'vysokoškolský',
#   'vzdělávání',
#   ',',
#   'odborný',
#   'příprava',
#   'a',
#   'mládež',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['dohoda',
#   'mezi',
#   'evropský',
#   'společenství',
#   'a',
#   'spojený',
#   'stát',
#   'v',
#   'oblast',
#   'vysokoškolský',
#   'vzdělávání',
#   'a',
#   'odborný',
#   'vzdělávání',
#   'a',
#   'příprava',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['systém',
#   'sociální',
#   'zabezpečení',
#   'pro',
#   'pracovník',
#   'a',
#   'jeho',
#   'rodina',
#   'pohybující',
#   'se',
#   'v',
#   'rámec',
#   'společenství',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['používání',
#   'cizí',
#   'a',
#   'místně',
#   'se',
#   'vyskytující',
#   'druh',
#   'v',
#   'akvakultura',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['společný',
#   'organizace',
#   'trh',
#   's',
#   'produkt',
#   'rybolov',
#   'a',
#   'akvakultura',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['změna',
#   'úmluva',
#   'o',
#   'přístup',
#   'k',
#   'informace',
#   ',',
#   'účast',
#   'veřejnost',
#   'na',
#   'rozhodování',
#   'a',
#   'přístup',
#   'k',
#   'právní',
#   'ochrana',
#   'v',
#   'záležitost',
#   'životní',
#   'prostředí',
#   '(',
#   'hlasování',
#   ')'],
#  ['8', '.'],
#  ['osvobození',
#   'zboží',
#   'dovážený',
#   'osoba',
#   'cestující',
#   'z',
#   'třetí',
#   'země',
#   'od',
#   'daň',
#   'z',
#   'přidaný',
#   'hodnota',
#   'a',
#   'spotřební',
#   'daň',
#   '(',
#   'hlasování',
#   ')'],
#  ['9', '.'],
#  ['třetí',
#   'příspěk',
#   'společenství',
#   'pro',
#   'fond',
#   'pro',
#   'kryt',
#   'reaktor',
#   'v',
#   'Černobyl',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['podpora',
#   'rozvoj',
#   'venkov',
#   'prostřednictví',
#   'EZFRV',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['žádost',
#   'o',
#   'ochrana',
#   'poslanecký',
#   'imunita',
#   'Gabriela',
#   'Albertini',
#   '(',
#   'hlasování',
#   ')'],
#  ['13', '.'],
#  ['žádost',
#   'o',
#   'ochrana',
#   'poslanecký',
#   'imunita',
#   'Gabriela',
#   'Albertini',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['žádost',
#   'o',
#   'ochrana',
#   'poslanecký',
#   'imunita',
#   'Gérard',
#   'Onesty',
#   '(',
#   'hlasování',
#   ')'],
#  ['15', '.'],
#  ['politika',
#   'společenství',
#   'v',
#   'oblast',
#   'mořský',
#   'životní',
#   'prostředí',
#   '(',
#   'hlasování',
#   ')'],
#  ['16', '.'],
#  ['měřící', 'zařízení', 'obsahující', 'rtuť', '(', 'hlasování', ')'],
#  ['18', '.'],
#  ['společný',
#   'podnik',
#   'pro',
#   'evropský',
#   'systém',
#   'řízení',
#   'letecký',
#   'provoz',
#   '(',
#   'SESAR',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['Nous',
#   'interrompons',
#   'à',
#   'présent',
#   'les',
#   'votes',
#   'pour',
#   'faire',
#   'plac',
#   'à',
#   'la',
#   'séance',
#   'solennelle',
#   '.'],
#  ['2', '.'],
#  ['strategie',
#   'pro',
#   'oblast',
#   'mořský',
#   'životní',
#   'prostředí',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['hypoteční', 'úvěr', '(', 'hlasování', ')'],
#  ['Nous',
#   'en',
#   'avons',
#   'à',
#   'présent',
#   'terminé',
#   'avec',
#   'les',
#   'votes',
#   '.'],
#  ['hlasování', '(', 'pokračování', ')'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'séance',
#   ',',
#   'suspendue',
#   'à',
#   '13',
#   'h',
#   '10',
#   ',',
#   'est',
#   'reprise',
#   'à',
#   '15',
#   'h',
#   '10',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'dílčí', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'séance', 'est', 'levée', 'à', '24', 'heures', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 's', 'abre', 'la', 'sesión', 'a', 'laso', '9.05', 'horas', ')'],
#  ['písemný', 'prohlášení', '(', 'předložení', ')', ':', 'viz', 'zápis'],
#  ['2', '.'],
#  ['systém',
#   'všeobecný',
#   'preference',
#   'evropský',
#   'unie',
#   '(',
#   'hlasování',
#   ')'],
#  ['1', '.'],
#  ['služba', 'na', 'vnitřní', 'trh', '(', 'hlasování', ')'],
#  ['s', 'cierra', 'elektrický', 'turno', 'de', 'votaciones', '.'],
#  ['hlasování', '(', 'pokračování', ')'],
#  ['Continuamos', 'con', 'elektrický', 'turno', 'de', 'votaciones', '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'sesión',
#   ',',
#   'suspendida',
#   'a',
#   'laso',
#   '13.10',
#   'horas',
#   ',',
#   'se',
#   'reanuda',
#   'a',
#   'laso',
#   '15.00',
#   'horas',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'politický', 'skupina', ':', 'viz', 'zápi'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'zasedání', 'skončit', 'v', '23', ':', '30', ')'],
#  ['sdělení', 'společný', 'postoj', 'rada', ':', 'viz', 'zápis'],
#  ['3', '.'],
#  ['úmluva',
#   'o',
#   'zákaz',
#   'biologický',
#   'a',
#   'toxinový',
#   'zbraň',
#   '(',
#   'BTWC',
#   ')',
#   ',',
#   'tříštivý',
#   'bomba',
#   'a',
#   'konvenční',
#   'zbraň',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['strategie',
#   'pro',
#   'region',
#   'baltský',
#   'moře',
#   'v',
#   'rámec',
#   'severní',
#   'dimenze',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['žena', 'v', 'mezinárodní', 'politika', '(', 'hlasování', ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'dílčí', 'zasedání', ':', 'viz', 'zápis'],
#  ['rozprava',
#   'o',
#   'případ',
#   'porušování',
#   'lidský',
#   'právo',
#   ',',
#   'demokracie',
#   'a',
#   'právní',
#   'stát',
#   '(',
#   'rozprava',
#   ')'],
#  ['1', '.'],
#  ['Etiopie', '(', 'hlasování', ')'],
#  ['2', '.'],
#  ['Bangladéš', '(', 'hlasování', ')'],
#  ['3', '.'],
#  ['Írán', '(', 'hlasování', ')'],
#  ['ten', 'být', 'hlasování', 'ukončit', '.'],
#  ['hlasování'],
#  ['další', 'bod', 'být', 'hlasování', '.'],
#  ['(',
#   'pokud',
#   'jít',
#   'o',
#   'výsledek',
#   'a',
#   'jiný',
#   'podrobnost',
#   'týkající',
#   'se',
#   'hlasování',
#   ':',
#   'viz',
#   'zápis',
#   ')'],
#  ['žádost', 'o', 'ochrana', 'parlamentní', 'imunita', ':', 'viz', 'zápis'],
#  ['žádost', 'o', 'zbavení', 'parlamentní', 'imunita', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['převod', 'prostředek', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   'uložený',
#   'v',
#   'rejstřík',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['přerušení', 'zasedání'],
#  ['přerušovat', 'zasedání', 'evropský', 'parlament', '.'],
#  ['(', 'zasedání', 'skončit', 'v', '17', ':', '05', ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný', 'prohlášení', '(', 'předložení', ')', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['převod', 'prostředek', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', ':', 'viz', 'zápis'],
#  ['ověřování', 'pověřovací', 'listina', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['sdělení', 'společný', 'postoj', 'rada', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'séance', 'est', 'levée', 'à', '0', 'h', '25', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 's', 'abre', 'la', 'sesión', 'a', 'laso', '9.00', 'horas', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['farmaceutický',
#   'účinný',
#   'látka',
#   '(',
#   'písemný',
#   'prohlášení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['1', '.'],
#  ['harmonizace',
#   'technický',
#   'požadavek',
#   'a',
#   'správní',
#   'postup',
#   'v',
#   'oblast',
#   'civilní',
#   'letectví',
#   '(',
#   'hlasování',
#   ')'],
#  ['2', '.'],
#  ['technický',
#   'požadavek',
#   'pro',
#   'plavidlo',
#   'vnitrozemský',
#   'plavba',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['dohoda',
#   'mezi',
#   'ES',
#   'a',
#   'kapverdský',
#   'republika',
#   'o',
#   'partnerství',
#   'v',
#   'odvětví',
#   'rybolov',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['záruka',
#   'společenství',
#   'evropský',
#   'investiční',
#   'banka',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['oprava',
#   'článek',
#   '139',
#   'jednací',
#   'řád',
#   '-',
#   'přechodný',
#   'ustanovení',
#   'o',
#   'jazyk',
#   '(',
#   'hlasování',
#   ')'],
#  ['9', '.'],
#  ['přistoupení', 'Rumunsko', '(', 'hlasování', ')'],
#  ['11', '.'],
#  ['pravidlo',
#   'pro',
#   'účast',
#   'na',
#   'sedmý',
#   'rámcový',
#   'program',
#   'ES',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['uvádění', 'pyrotechnický', 'výrobek', 'na', 'trh', '(', 'hlasování', ')'],
#  ['13', '.'],
#  ['evropský',
#   'systém',
#   'integrovaný',
#   'statistika',
#   'sociální',
#   'ochrana',
#   '(',
#   'ESISSO',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['pravidlo',
#   'pro',
#   'účast',
#   'na',
#   'sedmý',
#   'rámcový',
#   'program',
#   'ESAE',
#   '(',
#   'hlasování',
#   ')'],
#  ['15', '.'],
#  ['specifický',
#   'program',
#   '&quot;',
#   'člověk',
#   '&quot;',
#   '2007',
#   'až',
#   '2013',
#   '(',
#   'sedmý',
#   'rámcový',
#   'program',
#   'ES',
#   'pro',
#   'výzkum',
#   ',',
#   'technologický',
#   'rozvoj',
#   'a',
#   'demonstrace',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['16', '.'],
#  ['specifický',
#   'program',
#   '&quot;',
#   'myšlenka',
#   '&quot;',
#   '(',
#   'sedmý',
#   'rámcový',
#   'program',
#   'ES',
#   'pro',
#   'výzkum',
#   ',',
#   'technologický',
#   'rozvoj',
#   'a',
#   'demonstrace',
#   ',',
#   '2007',
#   'až',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['17', '.'],
#  ['specifický',
#   'program',
#   'kapacita',
#   '(',
#   'sedmý',
#   'rámcový',
#   'program',
#   'ES',
#   'pro',
#   'výzkum',
#   ',',
#   'technologický',
#   'rozvoj',
#   'a',
#   'demonstrace',
#   '2007',
#   'až',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['18', '.'],
#  ['specifický',
#   'program',
#   '&quot;',
#   'spolupráce',
#   '&quot;',
#   '2007',
#   'až',
#   '2013',
#   '(',
#   'sedmý',
#   'rámcový',
#   'program',
#   'ES',
#   'pro',
#   'výzkum',
#   ',',
#   'technologický',
#   'rozvoj',
#   'a',
#   'demonstrace',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['19', '.'],
#  ['specifický',
#   'program',
#   ',',
#   'který',
#   'mít',
#   'provést',
#   'společný',
#   'výzkumný',
#   'středisko',
#   'prostřednictví',
#   'přímý',
#   'akce',
#   '(',
#   'sedmý',
#   'rámcový',
#   'program',
#   'ES',
#   'pro',
#   'výzkum',
#   ',',
#   'technologický',
#   'rozvoj',
#   'a',
#   'demonstrace',
#   ',',
#   '2007',
#   'až',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['20', '.'],
#  ['specifický',
#   'program',
#   ',',
#   'který',
#   'mít',
#   'provést',
#   'společný',
#   'výzkumný',
#   'středisko',
#   'prostřednictví',
#   'přímý',
#   'akce',
#   '(',
#   'sedmý',
#   'rámcový',
#   'program',
#   'Euratom',
#   'pro',
#   'výzkum',
#   'a',
#   'odborný',
#   'příprava',
#   'v',
#   'oblast',
#   'jaderný',
#   'energie',
#   ',',
#   '2007',
#   'až',
#   '2011',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['22', '.'],
#  ['prostor',
#   'svoboda',
#   ',',
#   'bezpečnost',
#   'a',
#   'právo',
#   '(',
#   'hlasování',
#   ')'],
#  ['25', '.'],
#  ['čas',
#   'zařadit',
#   'vysoký',
#   'rychlost',
#   '-',
#   'zavedení',
#   'nový',
#   'partnerství',
#   'pro',
#   'zaměstnanost',
#   'a',
#   'růst',
#   '(',
#   'hlasování',
#   ')'],
#  ['That', 'concludes', 'the', 'vot', '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['přerušení', 'zasedání'],
#  ['i',
#   'declare',
#   'adjourned',
#   'the',
#   'session',
#   'of',
#   'the',
#   'European',
#   'Parliament',
#   '.'],
#  ['(',
#   'the',
#   'sitting',
#   'was',
#   'closed',
#   'atmosféra',
#   '12.20',
#   'page',
#   '.',
#   'město',
#   '.',
#   ')'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['žádost', 'o', 'ochrana', 'parlamentní', 'imunita', ':', 'viz', 'zápis'],
#  ['podepisování',
#   'akt',
#   'přijatý',
#   'postup',
#   'spolurozhodování',
#   ':',
#   'viz',
#   'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['písemný',
#   'prohlášení',
#   'a',
#   'otázka',
#   'k',
#   'ústní',
#   'zodpovězení',
#   '(',
#   'předložení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['petice', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Posiedzenie', 'zostało', 'zamknięte', 'o', 'godz', '.', '23.45', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 'zasedání', 'začít', 'v', '9', ':', '00', ')'],
#  ['rozprava',
#   'o',
#   'případ',
#   'porušování',
#   'lidský',
#   'právo',
#   ',',
#   'demokracie',
#   'a',
#   'právní',
#   'stát',
#   '(',
#   'oznámení',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['převod', 'prostředek', ':', 'viz', 'zápis'],
#  ['legislativní',
#   'a',
#   'pracovní',
#   'plán',
#   'komise',
#   '2007',
#   '(',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['schůzka',
#   'na',
#   'vysoký',
#   'úroveň',
#   'ruský',
#   '-',
#   'evropský',
#   'unie',
#   '(',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['hlasování'],
#  ['2', '.'],
#  ['jmenování', 'rumunský', 'člen', 'účetní', 'dvůr', '(', 'hlasování', ')'],
#  ['3', '.'],
#  ['modalita',
#   'účast',
#   'islandský',
#   'republika',
#   'a',
#   'norský',
#   'království',
#   'v',
#   'evropský',
#   'agentura',
#   'pro',
#   'řízení',
#   'operativní',
#   'spolupráce',
#   'na',
#   'vnější',
#   'hranice',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['prevence',
#   ',',
#   'tlumení',
#   'a',
#   'eradikace',
#   'některý',
#   'přenosný',
#   'spongiformní',
#   'encefalopatie',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['předkládání',
#   'statistický',
#   'údaj',
#   'o',
#   'vykládka',
#   'produkt',
#   'rybolov',
#   'v',
#   'členský',
#   'stát',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['ochrana',
#   'zletilý',
#   'osoba',
#   'a',
#   'lidský',
#   'důstojnost',
#   'a',
#   'o',
#   'právo',
#   'na',
#   'odpověď',
#   'v',
#   'souvislost',
#   's',
#   'konkurenceschopnost',
#   'evropský',
#   'průmysl',
#   'audiovizuální',
#   'a',
#   'on-line',
#   'informační',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['8', '.'],
#  ['program', 'clo', '2013', '(', 'hlasování', ')'],
#  ['9', '.'],
#  ['bezpapírový',
#   'prostředí',
#   'pro',
#   'clo',
#   'a',
#   'obchod',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['organizace',
#   'statistický',
#   'zjišťování',
#   'společenství',
#   'o',
#   'struktura',
#   'zemědělský',
#   'podnik',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['spolupráce',
#   'mezi',
#   'úřad',
#   'pro',
#   'vymáhání',
#   'majetek',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['výdaj', 'v', 'veterinární', 'oblast', '(', 'hlasování', ')'],
#  ['13', '.'],
#  ['ochrana',
#   'podzemní',
#   'voda',
#   'před',
#   'znečištění',
#   'a',
#   'zhoršování',
#   'stav',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['finanční',
#   'nástroj',
#   'pro',
#   'rozvojový',
#   'spolupráce',
#   '(',
#   'hlasování',
#   ')'],
#  ['15', '.'],
#  ['celní', 'kodex', 'společenství', '(', 'hlasování', ')'],
#  ['16', '.'],
#  ['oběh', 'krmný', 'směs', '(', 'hlasování', ')'],
#  ['17', '.'],
#  ['statistika',
#   'společenství',
#   'o',
#   'struktura',
#   'a',
#   'činnost',
#   'zahraniční',
#   'přidružený',
#   'společnost',
#   '(',
#   'hlasování',
#   ')'],
#  ['20', '.'],
#  ['finanční',
#   'nástroj',
#   'spolupráce',
#   's',
#   'průmyslový',
#   'a',
#   'jiný',
#   'země',
#   'a',
#   'území',
#   's',
#   'vysoký',
#   'přijmy',
#   '(',
#   'hlasování',
#   ')'],
#  ['Notre', 'séance', 'de', 'vote', 'est', 'close', '.'],
#  ['hlasování', '(', 'pokračování', ')'],
#  ['Nous',
#   'reprenon',
#   'à',
#   'présent',
#   'l',
#   "'",
#   'Heure',
#   'desátník',
#   'votes',
#   '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'séance',
#   ',',
#   'suspendue',
#   'à',
#   '13',
#   'h',
#   '05',
#   ',',
#   'est',
#   'reprise',
#   'à',
#   '15',
#   'heures',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'dílčí', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'the', 'sitting', 'was', 'closed', 'atmosféra', '23.40', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 's', 'abre', 'la', 'sesión', 'a', 'laso', '9.05', 'horas', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['následný',
#   'postup',
#   'na',
#   'základ',
#   'postoj',
#   'a',
#   'usnesení',
#   'parlament',
#   ':',
#   'viz',
#   'zápis'],
#  ['členství', 'v', 'politický', 'skupina', ':', 'viz', 'zápi'],
#  ['2', '.'],
#  ['změna',
#   'směrnice',
#   '67',
#   '/',
#   '548',
#   '/',
#   'EHS',
#   'o',
#   'bezpečný',
#   'látka',
#   '(',
#   'Reach',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['zahrnutí',
#   'bulharština',
#   'a',
#   'rumunština',
#   'mezi',
#   'jednací',
#   'jazyk',
#   'soudní',
#   'dvůr',
#   'evropský',
#   'společenství',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['zahrnutí',
#   'bulharština',
#   'a',
#   'rumunština',
#   'mezi',
#   'jednací',
#   'jazyk',
#   'soud',
#   'první',
#   'stupeň',
#   'evropský',
#   'společenství',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['evropský',
#   'rok',
#   'mezikulturní',
#   'dialog',
#   '(',
#   '2008',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['finanční',
#   'nařízení',
#   'o',
#   'souhrnný',
#   'rozpočet',
#   'evropský',
#   'společenství',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['návrh',
#   'opravný',
#   'rozpočet',
#   'číslo',
#   '.',
#   '6',
#   '/',
#   '2006',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['schvalování',
#   'typ',
#   'motorový',
#   'vozidlo',
#   's',
#   'ohled',
#   'na',
#   'emise',
#   'a',
#   'na',
#   'přístup',
#   'k',
#   'informace',
#   'o',
#   'oprava',
#   'vozidlo',
#   '(',
#   'hlasování',
#   ')'],
#  ['13', '.'],
#  ['DPH',
#   'na',
#   'služba',
#   'rozhlasový',
#   'a',
#   'televizní',
#   'vysílání',
#   'a',
#   'obdobný',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['legislativní',
#   'a',
#   'pracovní',
#   'plán',
#   'komise',
#   '2007',
#   '(',
#   'hlasování',
#   ')'],
#  ['použití',
#   'směrnice',
#   'rada',
#   '85',
#   '/',
#   '611',
#   '/',
#   'EHS',
#   '(',
#   'kolektivní',
#   'investování',
#   'do',
#   'převoditelný',
#   'cenný',
#   'papír',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'die',
#   'Sitzung',
#   'wird',
#   'um',
#   '14.05',
#   'Uhry',
#   'unterbrochen',
#   'und',
#   'um',
#   '15.00',
#   'Uhry',
#   'wieder',
#   'aufgenommen',
#   '.',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '23.25', ')', '.'],
#  ['zahájení', 'zasedání'],
#  ['(', 'die', 'Sitzung', 'wird', 'um', '9.05', 'Uhry', 'eröffnet', '.', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['podepisování',
#   'akt',
#   'přijatý',
#   'postup',
#   'spolurozhodování',
#   ':',
#   'viz',
#   'zápis'],
#  ['2', '.'],
#  ['návrh', 'souhrnný', 'rozpočet', 'na', 'rok', '2007', '(', 'hlasování', ')'],
#  ['3', '.'],
#  ['postup',
#   'pro',
#   'předchozí',
#   'prověření',
#   'a',
#   'konzultace',
#   'určitý',
#   'právní',
#   'a',
#   'správní',
#   'předpis',
#   'navrhovaný',
#   'členský',
#   'stát',
#   'v',
#   'oblast',
#   'doprava',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['odstranění',
#   'kontrola',
#   'na',
#   'hranice',
#   '(',
#   'v',
#   'silniční',
#   'a',
#   'vnitrozemský',
#   'vodní',
#   'doprava',
#   ')',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['sdělování',
#   'statistický',
#   'informace',
#   ',',
#   'na',
#   'který',
#   'se',
#   'vztahovat',
#   'statistický',
#   'důvěrnost',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['předkládání',
#   'statistika',
#   'o',
#   'rybolov',
#   'v',
#   'severovýchodní',
#   'atlantik',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['kritérium',
#   'společenství',
#   'pro',
#   'eradikace',
#   'a',
#   'sledování',
#   'některý',
#   'choroba',
#   'zvíře',
#   '(',
#   'kodifikovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['8', '.'],
#  ['dohoda',
#   'ES',
#   '-',
#   'Paraguay',
#   'o',
#   'některý',
#   'aspekt',
#   'letecký',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['9', '.'],
#  ['výzkum',
#   'a',
#   'vývoj',
#   'v',
#   'oblast',
#   'inteligentní',
#   'výrobní',
#   'systém',
#   '(',
#   'dohoda',
#   'EU',
#   's',
#   'Austrálie',
#   ',',
#   'Kanada',
#   ',',
#   'Norsko',
#   ',',
#   'Švýcarsko',
#   ',',
#   'Japonsko',
#   ',',
#   'Korea',
#   'a',
#   'spojený',
#   'stát',
#   'americký',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['společný',
#   'organizace',
#   'trh',
#   'v',
#   'odvětví',
#   'cukr',
#   '(',
#   'dočasný',
#   'režim',
#   'restrukturalizace',
#   'cukrovarnický',
#   'průmysl',
#   'po',
#   'rozšíření',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['prevence',
#   'užívání',
#   'droga',
#   'a',
#   'informování',
#   'veřejnost',
#   '(',
#   '2007',
#   '-',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['občanský',
#   'soudnictví',
#   '(',
#   '2007',
#   '-',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['13', '.'],
#  ['zřízení',
#   'evropský',
#   'fond',
#   'pro',
#   'uprchlík',
#   '(',
#   '2008',
#   '-',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['požadavek',
#   'týkající',
#   'se',
#   'dvojitý',
#   'trup',
#   'nebo',
#   'rovnocenný',
#   'konstrukce',
#   'u',
#   'ropný',
#   'tanker',
#   's',
#   'jednoduchý',
#   'trup',
#   '(',
#   'hlasování',
#   ')'],
#  ['15', '.'],
#  ['zřízení',
#   'evropský',
#   'fond',
#   'pro',
#   'začlenění',
#   'státní',
#   'příslušník',
#   'třetí',
#   'země',
#   '(',
#   '2007',
#   '-',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['17', '.'],
#  ['početní', 'složení', 'výbor', '(', 'hlasování', ')'],
#  ['18', '.'],
#  ['evropský',
#   'institut',
#   'pro',
#   'rovný',
#   'postavení',
#   'žena',
#   'a',
#   'muž',
#   '(',
#   'hlasování',
#   ')'],
#  ['19', '.'],
#  ['řidičský',
#   'průkaz',
#   '(',
#   'přepracovaný',
#   'znění',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['21', '.'],
#  ['změna',
#   'jednací',
#   'řád',
#   'evropský',
#   'parlament',
#   '(',
#   'kvestor',
#   ',',
#   'předsednictvo',
#   'výbor',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['24', '.'],
#  ['léčivý',
#   'přípravka',
#   'pro',
#   'pediatrický',
#   'použití',
#   '(',
#   'hlasování',
#   ')'],
#  ['26', '.'],
#  ['základní',
#   'právo',
#   'a',
#   'občanství',
#   '(',
#   '2007',
#   '-',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['27', '.'],
#  ['trestní',
#   'soudnictví',
#   '(',
#   '2007',
#   '-',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['28', '.'],
#  ['prevence',
#   'a',
#   'boj',
#   's',
#   'trestný',
#   'činnost',
#   '(',
#   '2007',
#   'až',
#   '2013',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['29', '.'],
#  ['vývoj',
#   'schengenský',
#   'informační',
#   'systém',
#   'druhý',
#   'generace',
#   '(',
#   'SIS',
#   'II',
#   ')',
#   '(',
#   'nařízení',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['30', '.'],
#  ['vývoj',
#   'schengenský',
#   'informační',
#   'systém',
#   'druhý',
#   'generace',
#   '(',
#   'SIS',
#   'II',
#   ')',
#   '(',
#   'rozhodnutí',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['32', '.'],
#  ['vízum',
#   'pro',
#   'překračování',
#   'vnější',
#   'hranice',
#   'členský',
#   'stát',
#   '(',
#   'hlasování',
#   ')'],
#  ['34', '.'],
#  ['ochrana',
#   'údaj',
#   'v',
#   'rámec',
#   'policejní',
#   'a',
#   'soudní',
#   'spolupráce',
#   'v',
#   'trestní',
#   'věc',
#   '(',
#   'hlasování',
#   ')'],
#  ['hlasování'],
#  ['elektrický',
#   'punto',
#   'siguiente',
#   'eso',
#   'elektrický',
#   'turno',
#   'de',
#   'votaciones',
#   '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'seduta',
#   ',',
#   'sospeso',
#   'alle',
#   '13.00',
#   ',',
#   'è',
#   'ripresa',
#   'alle',
#   '15.00',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['1', '.'],
#  ['situace', 'na', 'ostrov', 'Fidži', '(', 'hlasování', ')'],
#  ['2', '.'],
#  ['zapojení',
#   'síla',
#   'OSN',
#   'do',
#   'sexuální',
#   'zneužívání',
#   'v',
#   'Libérie',
#   'a',
#   'na',
#   'Haiti',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['Myanmar', '(', 'Barma', ')', '(', 'hlasování', ')'],
#  ['4', '.'],
#  ['haagský', 'úmluva', 'o', 'cenný', 'papír', '(', 'hlasování', ')'],
#  ['Nous',
#   'en',
#   'avons',
#   'à',
#   'présent',
#   'terminé',
#   'avec',
#   'l',
#   "'",
#   'Heure',
#   'desátník',
#   'votes',
#   '.'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['ověřování', 'pověřovací', 'listina', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   'uložený',
#   'v',
#   'rejstřík',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['přerušení', 'zasedání'],
#  ['být',
#   'déclare',
#   'interrompue',
#   'la',
#   'session',
#   'jít',
#   'Parlement',
#   'européen',
#   '.'],
#  ['(', 'Le', 'séance', 'est', 'levée', 'à', '16', 'h', '35', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['ověřování', 'pověřovací', 'listina', ':', 'viz', 'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['otázka',
#   'k',
#   'ústní',
#   'zodpovězení',
#   'a',
#   'písemný',
#   'prohlášení',
#   '(',
#   'předložení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['petice', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['následný',
#   'postup',
#   'na',
#   'základ',
#   'usnesení',
#   'parlament',
#   ':',
#   'viz',
#   'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 's', 'levanta', 'la', 'sesión', 'a', 'laso', '19.45', 'horas', ')'],
#  ['volba',
#   'místopředseda',
#   'evropský',
#   'parlament',
#   '(',
#   'lhůta',
#   'pro',
#   'předložení',
#   'nominace',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'die',
#   'Sitzung',
#   'wird',
#   'um',
#   '12.40',
#   'Uhry',
#   'unterbrochen',
#   'und',
#   'um',
#   '15.00',
#   'Uhry',
#   'wiederaufgenommen',
#   ')',
#   '.'],
#  ['volba',
#   'kvestor',
#   'evropský',
#   'parlament',
#   '(',
#   'lhůta',
#   'pro',
#   'předložení',
#   'nominace',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'die',
#   'Sitzung',
#   'wird',
#   'um',
#   '15.25',
#   'Uhry',
#   'unterbrochen',
#   'und',
#   'um',
#   '18.00',
#   'Uhry',
#   'wiederaufgenommen',
#   ')',
#   '.'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(',
#   'die',
#   'Sitzung',
#   'wird',
#   'um',
#   '18.15',
#   'Uhry',
#   'geschlossen',
#   '.',
#   ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 'die', 'Sitzung', 'wird', 'um', '9.35', 'Uhry', 'eröffnet', '.', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['složení',
#   'výbor',
#   '(',
#   'lhůta',
#   'pro',
#   'předložení',
#   'pozměňovací',
#   'návrh',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'seduta',
#   ',',
#   'sospeso',
#   'alle',
#   '19.00',
#   ',',
#   'è',
#   'ripresa',
#   'alle',
#   '21.00',
#   ')'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(',
#   'die',
#   'Sitzung',
#   'wird',
#   'um',
#   '23.25',
#   'Uhry',
#   'geschlossen',
#   '.',
#   ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['vyšetřovací',
#   'výbor',
#   'k',
#   'úpadek',
#   'společnost',
#   'Equitable',
#   'Life',
#   'Assurance',
#   'society',
#   '(',
#   'prodloužení',
#   'mandát',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['sdělení', 'předsednictvo', ':', 'viz', 'zápis'],
#  ['1', '.'],
#  ['složení', 'výbor', '(', 'hlasování', ')'],
#  ['2', '.'],
#  ['dohoda',
#   ',',
#   'který',
#   'se',
#   'měnit',
#   'dohoda',
#   'o',
#   'partnerství',
#   'mezi',
#   'stát',
#   'akt',
#   'na',
#   'jeden',
#   'strana',
#   'a',
#   'evropský',
#   'společenství',
#   'a',
#   'jeho',
#   'členský',
#   'stát',
#   'na',
#   'strana',
#   'druhý',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['osvědčení',
#   'strojvedoucí',
#   'obsluhující',
#   'hnací',
#   'vozidlo',
#   'a',
#   'vlak',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['právo',
#   'rozhodný',
#   'pro',
#   'mimosmluvní',
#   'závazkový',
#   'vztah',
#   '(',
#   '&quot;',
#   'Řím',
#   'II',
#   '&quot;',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['8', '.'],
#  ['sedmý',
#   'a',
#   'osmý',
#   'výroční',
#   'zpráva',
#   'o',
#   'vývoz',
#   'zbraň',
#   '(',
#   'hlasování',
#   ')'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['žádost', 'o', 'zbavení', 'parlamentní', 'imunita', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   'uložený',
#   'v',
#   'rejstřík',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['přerušení', 'zasedání'],
#  ['Dichiaro',
#   'interrot',
#   'la',
#   'session',
#   'del',
#   'Parlamento',
#   'europeo',
#   '.'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '13.00', ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['žádost', 'o', 'ochrana', 'parlamentní', 'imunita', ':', 'viz', 'zápis'],
#  ['členství',
#   'v',
#   'parlamentní',
#   'výbor',
#   '(',
#   'návrh',
#   'konference',
#   'předseda',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['následný',
#   'postup',
#   'na',
#   'základ',
#   'usnesení',
#   'parlament',
#   ':',
#   'viz',
#   'zápis'],
#  ['otázka',
#   'k',
#   'ústní',
#   'zodpovězení',
#   'a',
#   'písemný',
#   'prohlášení',
#   '(',
#   'předložení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['písemný',
#   'prohlášení',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['pořad', 'jednání', ':', 'viz', 'zápis'],
#  ['1', '.'],
#  ['návrh',
#   'na',
#   'členství',
#   'v',
#   'parlamentní',
#   'výbor',
#   '(',
#   'hlasování',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['hlasování'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '24.00', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 'the', 'sitting', 'was', 'opened', 'atmosféra', '09.05', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['1', '.'],
#  ['ochrana',
#   'cestující',
#   'před',
#   'zajištěný',
#   'zavazadlo',
#   '(',
#   'hlasování',
#   ')'],
#  ['2', '.'],
#  ['schvalování',
#   'motorový',
#   'vozidlo',
#   'z',
#   'hledisko',
#   'Polo',
#   'výhled',
#   'řidič',
#   'motorový',
#   'vozidlo',
#   'směr',
#   'dopředu',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['dohoda',
#   'o',
#   'vědeckotechnický',
#   'spolupráce',
#   'mezi',
#   'ES',
#   'a',
#   'korejský',
#   'republika',
#   '(',
#   'hlasování',
#   ')'],
#  ['4', '.'],
#  ['začlenění',
#   'udržitelnost',
#   'do',
#   'politika',
#   'rozvojový',
#   'spolupráce',
#   '(',
#   'hlasování',
#   ')'],
#  ['5', '.'],
#  ['návrh',
#   'opravný',
#   'rozpočet',
#   'číslo',
#   '.',
#   '1',
#   '/',
#   '2007',
#   '(',
#   'hlasování',
#   ')'],
#  ['7', '.'],
#  ['dohoda',
#   'mezi',
#   'evropský',
#   'společenství',
#   'a',
#   'gabonský',
#   'republika',
#   'o',
#   'partnerství',
#   'v',
#   'odvětví',
#   'rybolov',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['promlčet',
#   'doba',
#   'v',
#   'případ',
#   'újma',
#   'na',
#   'zdraví',
#   'a',
#   'smrtelný',
#   'úraz',
#   'v',
#   'přeshraniční',
#   'sporný',
#   'věc',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['vztah',
#   'EU',
#   's',
#   'tichomořský',
#   'ostrov',
#   '-',
#   'strategie',
#   'pro',
#   'posílení',
#   'partnerství',
#   '(',
#   'hlasování',
#   ')'],
#  ['13', '.'],
#  ['statut', 'evropský', 'soukromý', 'společnost', '(', 'hlasování', ')'],
#  ['Damit', 'ist', 'die', 'Abstimmungsstunde', 'beendet', '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['pověření', 'poslanec', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
# ...
#  ['jmenování',
#   'člen',
#   'meziparlamentní',
#   'delegace',
#   '(',
#   'návrh',
#   'konference',
#   'předseda',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['hepatitida', 'C', '(', 'písemný', 'prohlášení', ')', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '23.40', ')'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['1', '.'],
#  ['jmenování', 'v', 'meziparlamentní', 'delegace', '(', 'hlasování', ')'],
#  ['2', '.'],
#  ['činnost',
#   'společenství',
#   'v',
#   'oblast',
#   'přeshraniční',
#   'poskytování',
#   'zdravotní',
#   'péče',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['Bosna', 'a', 'Hercegovina', '(', 'hlasování', ')'],
#  ['8', '.'],
#  ['jednání',
#   'o',
#   'dohoda',
#   'o',
#   'přidružení',
#   'mezi',
#   'evropský',
#   'unie',
#   'a',
#   'země',
#   'střední',
#   'Amerika',
#   '(',
#   'hlasování',
#   ')'],
#  ['11', '.'],
#  ['ostrovní',
#   ',',
#   'přírodní',
#   'a',
#   'hospodářský',
#   'omezení',
#   'v',
#   'kontext',
#   'regionální',
#   'politika',
#   '(',
#   'hlasování',
#   ')'],
#  ['12', '.'],
#  ['místní',
#   'společenství',
#   'a',
#   'rozvojový',
#   'spolupráce',
#   '(',
#   'hlasování',
#   ')'],
#  ['Damit', 'ist', 'die', 'Abstimmungsstunde', 'beendet', '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'die',
#   'Sitzung',
#   'wird',
#   'um',
#   '12.55',
#   'Uhry',
#   'unterbrochen',
#   'und',
#   'um',
#   '15.00',
#   'Uhry',
#   'wieder',
#   'aufgenommen',
#   '.',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['rozprava',
#   'o',
#   'případ',
#   'porušování',
#   'lidský',
#   'právo',
#   ',',
#   'demokracie',
#   'a',
#   'právní',
#   'stát',
#   '(',
#   'rozprava',
#   ')'],
#  ['2', '.'],
#  ['Kambodža', '(', 'hlasování', ')'],
#  ['3', '.'],
#  ['Nigérie', '(', 'hlasování', ')'],
#  ['4', '.'],
#  ['napadení',
#   'Galina',
#   'kozel',
#   ',',
#   'členka',
#   'správní',
#   'rada',
#   'organizace',
#   'Mari',
#   'Ušem',
#   'a',
#   'šéfredaktorka',
#   'literární',
#   'časopis',
#   'Ontšõko',
#   '(',
#   'hlasování',
#   ')'],
#  ['L', "'", 'Heure', 'desátník', 'votes', 'est', 'close', '.'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['sdělení', 'společný', 'postoj', 'rada', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   'uložený',
#   'v',
#   'rejstřík',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['písemný',
#   'prohlášení',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['otázka',
#   'k',
#   'ústní',
#   'zodpovězení',
#   'a',
#   'písemný',
#   'prohlášení',
#   '(',
#   'předložení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['následný',
#   'postup',
#   'na',
#   'základ',
#   'usnesení',
#   'parlament',
#   ':',
#   'viz',
#   'zápis'],
#  ['pořad', 'jednání', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 's', 'cierra', 'la', 'sesión', 'a', 'laso', '00.05', 'horas', ')'],
#  ['zahájení', 'zasedání'],
#  ['členství', 'v', 'politický', 'skupina', ':', 'viz', 'zápi'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['(', 'die', 'Sitzung', 'wird', 'um', '9.10', 'Uhry', 'eröffnet', '.', ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['2', '.'],
#  ['účast',
#   'společenství',
#   'na',
#   'zvýšení',
#   'kapitál',
#   'evropský',
#   'investiční',
#   'fond',
#   '(',
#   'hlasování',
#   ')'],
#  ['3', '.'],
#  ['žádost',
#   'o',
#   'ochrana',
#   'parlamentní',
#   'imunita',
#   'pan',
#   'Giuseppe',
#   'Garganiho',
#   '(',
#   'hlasování',
#   ')'],
#  ['6', '.'],
#  ['soulad', 's', 'požadavek', 'na', 'stát', 'vlajka', '(', 'hlasování', ')'],
#  ['7', '.'],
#  ['odpovědnost',
#   'za',
#   'škoda',
#   'a',
#   'finanční',
#   'záruka',
#   'majitel',
#   'plavidlo',
#   '(',
#   'hlasování',
#   ')'],
#  ['9', '.'],
#  ['Bezpečnost',
#   'v',
#   'souvislost',
#   's',
#   'fotbalový',
#   'zápas',
#   '(',
#   'hlasování',
#   ')'],
#  ['10', '.'],
#  ['budoucnost', 'Kosovo', 'a', 'role', 'EU', '(', 'hlasování', ')'],
#  ['11', '.'],
#  ['budoucnost', 'vlastní', 'zdroj', 'evropský', 'unie', '(', 'hlasování', ')'],
#  ['12', '.'],
#  ['rozpočtový', 'směr', 'na', 'rok', '2008', '(', 'hlasování', ')'],
#  ['13', '.'],
#  ['budoucnost',
#   'profesionální',
#   'fotbal',
#   'v',
#   'Evropa',
#   '(',
#   'hlasování',
#   ')'],
#  ['14', '.'],
#  ['integrace', 'nový', 'členský', 'stát', 'do', 'SZP', '(', 'hlasování', ')'],
#  ['s', 'cierra', 'elektrický', 'turno', 'de', 'votaciones', '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['sdělení', 'společný', 'postoj', 'rada', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'meziparlamentní', 'delegace', ':', 'viz', 'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['předání', 'přijatý', 'text', 'během', 'schůze', ':', 'viz', 'zápis'],
#  ['termín', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['předložení', 'dokument', ':', 'viz', 'zápis'],
#  ['text', 'smlouva', 'dodaný', 'rada', ':', 'viz', 'zápis'],
#  ['rozhodnutí', 'o', 'určitý', 'dokument', ':', 'viz', 'zápis'],
#  ['otázka',
#   'k',
#   'ústní',
#   'zodpovězení',
#   'a',
#   'písemný',
#   'prohlášení',
#   '(',
#   'předložení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['písemný',
#   'prohlášení',
#   '(',
#   'článek',
#   '116',
#   'jednací',
#   'řád',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['následný',
#   'postup',
#   'na',
#   'základ',
#   'usnesení',
#   'parlament',
#   ':',
#   'viz',
#   'zápis'],
#  ['složení', 'parlament', ':', 'viz', 'zápis'],
#  ['členství', 'v', 'výbor', 'a', 'delegace', ':', 'viz', 'zápis'],
#  ['podepisování',
#   'akt',
#   'přijatý',
#   'postup',
#   'spolurozhodování',
#   ':',
#   'viz',
#   'zápis'],
#  ['prohlášení', 'o', 'finanční', 'zájem', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Posiedzenie', 'zostało', 'zamknięte', 'o', 'godz', '.', '00.05', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'aperta', 'alle', '9.00', ')'],
#  ['rozprava',
#   'o',
#   'případ',
#   'porušování',
#   'lidský',
#   'právo',
#   ',',
#   'demokracie',
#   'a',
#   'právní',
#   'stát',
#   '(',
#   'oznámení',
#   'předložený',
#   'návrh',
#   'usnesení',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['1', '.'],
#  ['dohoda',
#   'mezi',
#   'ES',
#   'a',
#   'Malajsie',
#   'o',
#   'některý',
#   'aspekt',
#   'letecký',
#   'služba',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Costa'],
#  ['3', '.'],
#  ['kvóta',
#   'na',
#   'dovoz',
#   'surový',
#   'třtinový',
#   'cukr',
#   'do',
#   'Bulharsko',
#   'a',
#   'Rumunsko',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Graefe', 'za', 'Baringdorf'],
#  ['4', '.'],
#  ['žádost',
#   'o',
#   'zbavení',
#   'parlamentní',
#   'imunita',
#   'pan',
#   'Vurala',
#   'Ögera',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Speroeň'],
#  ['5', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'oddíl',
#   'IV',
#   '-',
#   'soudní',
#   'dvůr',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Caspar'],
#  ['6', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'oddíl',
#   'V',
#   ',',
#   'účetní',
#   'dvůr',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Caspar'],
#  ['7', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   ':',
#   'oddíl',
#   'VI',
#   '-',
#   'evropský',
#   'hospodářský',
#   'a',
#   'sociální',
#   'výbor',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Caspar'],
#  ['8', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'oddíl',
#   'VIII',
#   'a',
#   '-',
#   'evropský',
#   'veřejný',
#   'ochránce',
#   'právo',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Caspar'],
#  ['9', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'oddíl',
#   'VIII',
#   'B',
#   '-',
#   'evropský',
#   'inspektor',
#   'ochrana',
#   'údaj',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Caspar'],
#  ['10', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'šestý',
#   ',',
#   'sedmý',
#   ',',
#   'osmý',
#   'a',
#   'devátý',
#   'evropský',
#   'rozvojový',
#   'fond',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Camre'],
#  ['11', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'středisko',
#   'pro',
#   'rozvoj',
#   'odborný',
#   'vzdělávání',
#   '(',
#   'CEDEFOP',
#   ')',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['12', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'nadace',
#   'pro',
#   'zlepšení',
#   'životní',
#   'a',
#   'pracovní',
#   'podmínka',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['13', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'středisko',
#   'pro',
#   'sledování',
#   'rasismus',
#   'a',
#   'xenofobie',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['14', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'monitorovací',
#   'centrum',
#   'pro',
#   'droga',
#   'a',
#   'drogový',
#   'závislost',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['15', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'agentura',
#   'pro',
#   'životní',
#   'prostředí',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['16', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'agentura',
#   'pro',
#   'bezpečnost',
#   'a',
#   'zdraví',
#   'při',
#   'práce',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['17', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'překladatelský',
#   'středisko',
#   'pro',
#   'instituce',
#   'evropský',
#   'unie',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['18', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'agentura',
#   'pro',
#   'léčivý',
#   'přípravek',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['19', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'Eurojust',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['20', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'nadace',
#   'pro',
#   'odborný',
#   'vzdělávání',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['21', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'agentura',
#   'pro',
#   'námořní',
#   'bezpečnost',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['22', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'agentura',
#   'pro',
#   'letecký',
#   'bezpečnost',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['23', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'úřad',
#   'pro',
#   'bezpečnost',
#   'potravina',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['24', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'středisko',
#   'pro',
#   'prevence',
#   'a',
#   'kontrola',
#   'nemoc',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['25', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'agentura',
#   'pro',
#   'bezpečnost',
#   'síť',
#   'a',
#   'informace',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['33', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'oddíl',
#   'VII',
#   '-',
#   'výbor',
#   'region',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Caspar'],
#  ['34', '.'],
#  ['absolutorium',
#   'za',
#   'rozpočtový',
#   'rok',
#   '2005',
#   ':',
#   'evropský',
#   'agentura',
#   'pro',
#   'obnova',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Herczog'],
#  ['35', '.'],
#  ['boj',
#   's',
#   'HIV',
#   '/',
#   'AIDS',
#   'uvnitř',
#   'evropský',
#   'unie',
#   'a',
#   'v',
#   'sousední',
#   'země',
#   ',',
#   '2006',
#   '-',
#   '2009',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Relazione', ':', 'Andrejevs'],
#  ['Ciò', 'conclude', 'il', 'turno', 'di', 'votazioni', '.'],
#  ['oprava',
#   'hlasování',
#   'a',
#   'sdělení',
#   'o',
#   'úmysl',
#   'hlasovat',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'seduta',
#   ',',
#   'sospeso',
#   'alle',
#   '13.20',
#   ',',
#   'è',
#   'ripresa',
#   'alle',
#   '15.05',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['námitka',
#   'přípustnost',
#   '(',
#   'homofobie',
#   'v',
#   'Evropa',
#   ')',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'a',
#   'sessão',
#   ',',
#   'suspensa',
#   'às',
#   '19',
#   'h',
#   '35',
#   ',',
#   'é',
#   'reiniciada',
#   'às',
#   '21',
#   'h',
#   '00',
#   ')'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'seduta', 'è', 'tolta', 'alle', '23.45', ')'],
#  ['zahájení', 'zasedání'],
#  ['(', 'Le', 'séance', 'est', 'ouverte', 'à', '9', 'h', '00', ')'],
#  ['1', '.'],
#  ['předávání', 'údaj', 'z', 'národní', 'účet', '(', 'hlasování', ')'],
#  ['-', 'Rapport', 'García', '-', 'Margallo', 'y', 'Marfil'],
#  ['(',
#   'Certains',
#   'députés',
#   'continuent',
#   'de',
#   'protester',
#   'et',
#   'de',
#   'demander',
#   'la',
#   'parola',
#   ')'],
#  ['2', '.'],
#  ['mnohostranný',
#   'dohoda',
#   'o',
#   'vytvoření',
#   'společný',
#   'evropský',
#   'vzdušný',
#   'prostor',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Rapport', 'Lichtenberger'],
#  ['(', 'Après', 'le', 'vot', ',', 'le', 'tumulíst', 's', "'", 'amplifie', ')'],
#  ['2', '.'],
#  ['rámcový',
#   'dohoda',
#   'o',
#   'mnohostranný',
#   'program',
#   'ruský',
#   'federace',
#   'pro',
#   'životní',
#   'prostředí',
#   'v',
#   'jaderný',
#   'oblast',
#   'a',
#   'protokol',
#   'o',
#   'právní',
#   'nárok',
#   ',',
#   'soudní',
#   'řízení',
#   'a',
#   'náhrada',
#   'škoda',
#   'k',
#   'tento',
#   'rámcový',
#   'dohoda',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Rapport', 'Remek'],
#  ['hlasování', '(', 'pokračování', ')'],
#  ['1', '.'],
#  ['vyhodnocování',
#   'a',
#   'zvládání',
#   'povodňový',
#   'riziko',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Recommandation', 'Seeber'],
#  ['hlasování', '(', 'pokračování', ')'],
#  ['6', '.'],
#  ['státní', 'přístavní', 'inspekce', '(', 'hlasování', ')'],
#  ['-', 'Rapport', 'Vlasta'],
#  ['7', '.'],
#  ['subjekt',
#   'pověřený',
#   'inspekce',
#   'a',
#   'prohlídka',
#   'loď',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Rapport', 'de', 'Grandes', 'Pascual'],
#  ['9', '.'],
#  ['dočasný', 'výbor', 'pro', 'změna', 'klima', '(', 'hlasování', ')'],
#  ['-', 'Proposition', 'de', 'décision'],
#  ['10', '.'],
#  ['žaloba',
#   'o',
#   'náhrada',
#   'škoda',
#   'způsobený',
#   'porušení',
#   'antimonopolní',
#   'pravidlo',
#   'ES',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Rapport', 'Sánchez', 'Presedo'],
#  ['11', '.'],
#  ['mnohostranný',
#   'dohoda',
#   'o',
#   'vytvoření',
#   'společný',
#   'evropský',
#   'letecký',
#   'prostor',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Proposition', 'de', 'résolution'],
#  ['12', '.'],
#  ['tematický',
#   'strategie',
#   'pro',
#   'udržitelný',
#   'využívání',
#   'přírodní',
#   'zdroj',
#   '(',
#   'hlasování',
#   ')'],
#  ['-', 'Rapport', 'Liotard'],
#  ['hlasování', '(', 'pokračování', ')'],
#  ['oprava',
#   'hlasování',
#   'z',
#   'předcházející',
#   'zasedání',
#   ':',
#   'viz',
#   'zápis'],
#  ['(',
#   'Le',
#   'seduta',
#   ',',
#   'sospeso',
#   'alle',
#   '14.00',
#   ',',
#   'è',
#   'ripresa',
#   'alle',
#   '15.00',
#   ')'],
#  ['schválení', 'zápis', 'z', 'předchozí', 'zasedání', ':', 'viz', 'zápis'],
#  ['pořad', 'jednání', 'příští', 'zasedání', ':', 'viz', 'zápis'],
#  ['ukončení', 'zasedání'],
#  ['(', 'Le', 'séance', 'est', 'levée', 'à', '23', 'h', '25', ')'],
#  ...]
